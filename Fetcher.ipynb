# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
URL = 'https://www.tomshardware.com/reviews/gpu-hierarchy,4388.html'

htmlcontent = requests.get(URL).text

soup = BeautifulSoup(htmlcontent, 'html.parser')

results = [soup.find_all("td", {"class": "firstcol"})]

GPUs = []
for i in results[0]:
    a = i.get_text().strip('<td class="firstcol">')
    GPUs.append(a)

print(GPUs)
# Out:
# ['Nvidia GeForce RTX 3090', 'Nvidia GeForce RTX 3080', 'Nvidia Titan RTX', 'Nvidia GeForce RTX 2080 T', 'Nvidia Titan V', 'Nvidia GeForce RTX 2080 Supe', 'Nvidia GeForce RTX 2080', 'Nvidia Titan Xp', 'Nvidia GeForce RTX 2070 Supe', 'AMD Radeon VII', 'Nvidia GeForce GTX 1080 T', 'AMD Radeon RX 5700 XT', 'Nvidia GeForce RTX 2070', 'AMD Radeon RX 5700', 'Nvidia GeForce RTX 2060 Supe', 'AMD Radeon RX Vega 64', 'AMD Radeon RX 5600 XT', 'Nvidia GeForce GTX 1080', 'Nvidia GeForce RTX 2060', 'AMD Radeon RX Vega 56', 'Nvidia GeForce GTX 1070 T', 'Nvidia GeForce GTX 1660 T', 'Nvidia GeForce GTX 1660 Supe', 'Nvidia GeForce GTX 1070', 'Nvidia GTX Titan X (Maxwell)', 'Nvidia GeForce GTX 980 T', 'Nvidia GeForce GTX 1660', 'AMD Radeon R9 Fury X', 'AMD Radeon RX 590', 'AMD Radeon RX 5500 XT 8GB', 'AMD Radeon RX 580 8GB', 'Nvidia GeForce GTX 1650 Supe', 'AMD Radeon RX 5500 XT 4GB', 'AMD Radeon R9 390', 'Nvidia GeForce GTX 1060 6GB', 'Nvidia GeForce GTX 980', 'AMD Radeon RX 570 4GB', 'Nvidia GTX 1650 GDDR6', 'Nvidia GeForce GTX 1060 3GB', 'Nvidia GeForce GTX 970', 'Nvidia GeForce GTX 1650', 'Nvidia GeForce GTX 1050 T', 'AMD Radeon RX 560 4GB', 'Nvidia GeForce GTX 1050', 'AMD Radeon RX 550', 'Nvidia GeForce GT 1030', 'AMD Vega 11 (R5 3400G)', 'AMD Vega 8 (R3 3200G)', 'Intel Iris Plus (i7-1065G7)', 'Intel UHD Graphics 630 (i7-9700K)']

# %%
URL = 'https://www.tomshardware.com/reviews/gpu-hierarchy,4388.html'

htmlcontent = requests.get(URL).text

soup = BeautifulSoup(htmlcontent, 'html.parser')

Scoreresults = [soup.find_all("td")]
print(Scoreresults)
# Out:
# [[<td class="firstcol">Nvidia GeForce RTX 3090</td>, <td>100.0%</td>, <td>GA102</td>, <td>1440/1695 MHz</td>, <td>24GB GDDR6X</td>, <td>350W</td>, <td></td>, <td class="firstcol">Nvidia GeForce RTX 3080</td>, <td>93.0%</td>, <td>GA102</td>, <td>1500/1710 MHz</td>, <td>10GB GDDR6X</td>, <td>320W</td>, <td></td>, <td class="firstcol">Nvidia Titan RTX</td>, <td>79.3%</td>, <td>TU102</td>, <td>1350/1770 MHz</td>, <td>24GB GDDR6</td>, <td>280W</td>, <td><span class="hawk-widget" data-display-type="classic" data-model-name="Titan RTX" data-rows="1" data-show-link="0" data-show-reviews="none" data-widget-type="price"><a data-original-href="https://www.amazon.com/nvidia-Titan-Graphic-Cards-900-1G150-2500-000/dp/B07L8YGDL5?tag=hawk-future-20&amp;ascsubtag=tomshardware&amp;ascsubtag=%site%%transactionId%-gclid-%gclid%-Fallback" href="https://target.georiot.com/Proxy.ashx?tsid=45723&amp;GR_URL=https%3A%2F%2Fwww.amazon.com%2Fnvidia-Titan-Graphic-Cards-900-1G150-2500-000%2Fdp%2FB07L8YGDL5%3Ftag%3Dhawk-future-20%26ascsubtag%3Dtomshardware-us-5027206239413341000-20" rel="nofollow noopener" target="_blank">Titan RTX</a></span></td>, <td class="firstcol">Nvidia GeForce RTX 2080 Ti</td>, <td>77.5%</td>, <td>TU102</td>, <td>1350/1635 MHz</td>, <td>11GB GDDR6</td>, <td>260W</td>, <td><span class="hawk-widget" data-model-name="Nvidia GeForce RTX 2080 Ti" data-rows="1" data-show-link="0" data-show-reviews="none" data-widget-type="price"><a data-original-href="https://click.linksynergy.com/deeplink?id=Cty0dj6o3sg&amp;mid=38606&amp;u1=TomsHardware&amp;murl=https%3A%2F%2Fwww.bestbuy.com%2Fsite%2Fnvidia-geforce-rtx-2080-ti-founders-edition-11gb-gddr6-pci-express-3-0-graphics-card%2F6291646.p%3FskuId%3D6291646" href="https://bestbuy.7tiv.net/c/221109/614286/10014?subId1=tomshardware-us-2849051375549714400&amp;u=https%3A%2F%2Fwww.bestbuy.com%2Fsite%2Fnvidia-geforce-rtx-2080-ti-founders-edition-11gb-gddr6-pci-express-3-0-graphics-card%2F6291646.p%3FskuId%3D6291646" rel="nofollow noopener" target="_blank">Nvidia GeForce RTX 2080 Ti</a></span></td>, <td class="firstcol">Nvidia Titan V</td>, <td>68.7%</td>, <td>GV100</td>, <td>1200/1455 MHz</td>, <td>12GB HBM2</td>, <td>250W</td>, <td></td>, <td class="firstcol">Nvidia GeForce RTX 2080 Super</td>, <td>66.9%</td>, <td>TU104</td>, <td>1650/1815 MHz</td>, <td>8GB GDDR6</td>, <td>250W</td>, <td><span class="hawk-widget" data-model-name="GeForce RTX 2080 Super" data-rows="1" data-show-link="0" data-show-reviews="none" data-widget-type="price"><a data-original-href="https://www.amazon.com/GIGABYTE-GeForce-Graphics-256-Bit-GV-N208STURBO-8GC/dp/B07V1DJ9KG?ascsubtag=%site%%transactionId%-gclid-%gclid%-Fallback" href="https://target.georiot.com/Proxy.ashx?tsid=45723&amp;GR_URL=https%3A%2F%2Fwww.amazon.com%2FGIGABYTE-GeForce-Graphics-256-Bit-GV-N208STURBO-8GC%2Fdp%2FB07V1DJ9KG%3Ftag%3Dhawk-future-20%26ascsubtag%3Dtomshardware-us-1298961085559079400-20" rel="nofollow noopener" target="_blank">GeForce RTX 2080 Super</a></span></td>, <td class="firstcol">Nvidia GeForce RTX 2080</td>, <td>62.6%</td>, <td>TU104</td>, <td>1515/1800 MHz</td>, <td>8GB GDDR6</td>, <td>225W</td>, <td><span class="hawk-widget" data-model-name="GeForce RTX 2080" data-rows="1" data-show-link="0" data-show-reviews="none" data-widget-type="price"><a data-original-href="https://click.linksynergy.com/deeplink?id=Cty0dj6o3sg&amp;mid=38606&amp;u1=TomsHardware&amp;murl=https%3A%2F%2Fwww.bestbuy.com%2Fsite%2Fnvidia-geforce-rtx-2080-founders-edition-8gb-gddr6-pci-express-3-0-graphics-card%2F6291648.p%3FskuId%3D6291648" href="https://bestbuy.7tiv.net/c/221109/614286/10014?subId1=tomshardware-us-1009785834669418100&amp;u=https%3A%2F%2Fwww.bestbuy.com%2Fsite%2Fnvidia-geforce-rtx-2080-founders-edition-8gb-gddr6-pci-express-3-0-graphics-card%2F6291648.p%3FskuId%3D6291648" rel="nofollow noopener" target="_blank">GeForce RTX 2080</a></span></td>, <td class="firstcol">Nvidia Titan Xp</td>, <td>61.2%</td>, <td>GP102</td>, <td>1405/1480 MHz</td>, <td>12GB GDDR5X</td> ...

# %%
ScoreresultsC = [results]

# %%
url = "https://www.tomshardware.com/reviews/gpu-hierarchy,4388.html"

r = requests.get(url)
df_list = pd.read_html(r.text) # this parses all the tables in webpages to a list
df = df_list[0]

# %%
df.rename(columns={'Unnamed: 0':'GPUName'})
# Out:
#                               GPUName   Score          GPU     Base/Boost  \
# 0             Nvidia GeForce RTX 3090  100.0%        GA102  1440/1695 MHz
# 1             Nvidia GeForce RTX 3080   93.0%        GA102  1500/1710 MHz
# 2                    Nvidia Titan RTX   79.3%        TU102  1350/1770 MHz
# 3          Nvidia GeForce RTX 2080 Ti   77.5%        TU102  1350/1635 MHz
# 4                      Nvidia Titan V   68.7%        GV100  1200/1455 MHz
# 5       Nvidia GeForce RTX 2080 Super   66.9%        TU104  1650/1815 MHz
# 6             Nvidia GeForce RTX 2080   62.6%        TU104  1515/1800 MHz
# 7                     Nvidia Titan Xp   61.2%        GP102  1405/1480 MHz
# 8       Nvidia GeForce RTX 2070 Super   59.7%        TU104  1605/1770 MHz
# 9                      AMD Radeon VII   58.9%      Vega 20  1400/1750 MHz
# 10         Nvidia GeForce GTX 1080 Ti   57.8%        GP102  1480/1582 MHz
# 11              AMD Radeon RX 5700 XT   56.7%      Navi 10  1605/1905 MHz
# 12            Nvidia GeForce RTX 2070   53.1%        TU106  1410/1710 MHz
# 13                 AMD Radeon RX 5700   51.4%      Navi 10  1465/1725 MHz
# 14      Nvidia GeForce RTX 2060 Super   50.6%        TU106  1470/1650 MHz
# 15              AMD Radeon RX Vega 64   48.5%      Vega 10  1274/1546 MHz
# 16              AMD Radeon RX 5600 XT   46.6%      Navi 10     ?/1615 MHz
# 17            Nvidia GeForce GTX 1080   45.3%        GP104  1607/1733 MHz
# 18            Nvidia GeForce RTX 2060   44.9%        TU106  1365/1680 MHz
# 19              AMD Radeon RX Vega 56   42.8%      Vega 10  1156/1471 MHz
# 20         Nvidia GeForce GTX 1070 Ti   41.9%        GP104  1607/1683 MHz
# 21         Nvidia GeForce GTX 1660 Ti   38.0%        TU116  1365/1680 MHz
# 22      Nvidia GeForce GTX 1660 Super   37.9%        TU116  1530/1785 MHz
# 23            Nvidia GeForce GTX 1070   36.8%        GP104  1506/1683 MHz
# 24       Nvidia GTX Titan X (Maxwell)   35.3%        GM200  1000/1075 MHz
# 25          Nvidia GeForce GTX 980 Ti   33.0%        GM200  1000/1075 MHz
# 26            Nvidia GeForce GTX 1660   32.9%        TU116  1530/1785 MHz
# 27               AMD Radeon R9 Fury X   32.8%         Fiji       1050 MHz
# 28                  AMD Radeon RX 590   32.4%   Polaris 30  1469/1545 MHz
# 29          AMD Radeon RX 5500 XT 8GB   31.9%      Navi 14     ?/1717 MHz
# 30              AMD Radeon RX 580 8GB   30.9%   Polaris 20  1257/1340 MHz
# 31      Nvidia GeForce GTX 1650 Super   28.5%        TU116  1530/1725 MHz
# 32          AMD Radeon RX 5500 XT 4GB   28.4%      Navi 14     ?/1717 MHz
# 33                  AMD Radeon R9 390   27.2%       Hawaii       1000 MHz
# 34        Nvidia GeForce GTX 1060 6GB   26.5%        GP106  1506/1708 MHz
# 35             Nvidia GeForce GTX 980   26.5%        GM204  1126/1216 MHz
# 36              AMD Radeon RX 570 4GB   25.3%   Polaris 20  1168/1244 MHz
# 37              Nvidia GTX 1650 GDDR6   23.9%        TU117  1410/1590 MHz
# 38        Nvidia GeForce GTX 1060 3GB   22.3%        GP106  1506/1708 MHz
# 39             Nvidia GeForce GTX 970   22.2%        GM204  1050/1178 MHz
# 40            Nvidia GeForce GTX 1650   20.9%        TU117  1485/1665 MHz
# 41         Nvidia GeForce GTX 1050 Ti   16.1%        GP107  1290/1392 MHz
# 42              AMD Radeon RX 560 4GB   12.6%   Polaris 21  1175/1275 MHz
# 43            Nvidia GeForce GTX 1050   12.2%        GP107  1354/1455 MHz
# 44                  AMD Radeon RX 550    8.0%   Polaris 22  1100/1183 MHz
# 45             Nvidia GeForce GT 1030    5.8%        GP108  1228/1468 MHz
# 46             AMD Vega 11 (R5 3400G)    5.5%      Vega 11       1400 MHz
# 47              AMD Vega 8 (R3 3200G)    4.9%       Vega 8       1250 MHz
# 48        Intel Iris Plus (i7-1065G7)    3.3%  Gen11 ICL-U       1100 MHz
# 49  Intel UHD Graphics 630 (i7-9700K)    2.0%   Gen9.5 CFL       1200 MHz
#
#                 Memory Power                                  Buy
# 0          24GB GDDR6X  350W                                  NaN
# 1          10GB GDDR6X  320W                                  NaN
# 2           24GB GDDR6  280W                            Titan RTX
# 3           11GB GDDR6  260W           Nvidia GeForce RTX 2080 Ti
# 4            12GB HBM2  250W                                  NaN
# 5            8GB GDDR6  250W               GeForce RTX 2080 Super
# 6            8GB GDDR6  225W                     GeForce RTX 2080
# 7          12GB GDDR5X  250W                  GeForce GTX Titan X
# 8            8GB GDDR6  215W               GeForce RTX 2070 Super
# 9            16GB HBM2  300W                           Radeon VII
# 10         11GB GDDR5X  250W           Nvidia GeForce GTX 1080 Ti
# 11           8GB GDDR6  225W                AMD Radeon RX 5700 XT
# 12           8GB GDDR6  185W                             RTX 2070
# 13           8GB GDDR6  185W                   AMD Radeon RX 5700
# 14           8GB GDDR6  175W               GeForce RTX 2060 Super
# 15            8GB HBM2  295W           Gigabyte Radeon RX Vega 64
# 16           6GB GDDR6  150W                    Radeon RX 5600 XT
# 17          8GB GDDR5X  180W              Nvidia GeForce GTX 1080
# 18           6GB GDDR6  160W           Nvidia GeForce RTX 2060 FE
# 19            8GB HBM2  210W                    Radeon RX Vega 56
# 20           8GB GDDR5  180W                  GeForce GTX 1070 Ti
# 21           6GB GDDR6  120W              GeForce GTX 1660 Ti 6GB
# 22           6GB GDDR6  125W               GeForce GTX 1660 Super
# 23           8GB GDDR5  150W                         MSI GTX 1070
# 24          12GB GDDR5   250                                  NaN
# 25           6GB GDDR5  250W                   GeForce GTX 980 Ti
# 26           6GB GDDR5  120W                     Geforce GTX 1660
# 27             4GB HBM  275W                 AMD Radeon R9 Fury X
# 28           8GB GDDR5  225W                        Radeon RX 590
# 29           8GB GDDR6  130W            AMD Radeon RX 5500 XT 8GB
# 30           8GB GDDR5  185W                    AMD Radeon RX 580
# 31           4GB GDDR6  100W        Nvidia GeForce GTX 1650 Super
# 32           4GB GDDR6  130W            AMD Radeon RX 5500 XT 4GB
# 33           8GB GDDR5  275W                    AMD Radeon R9 390
# 34           6GB GDDR5  120W          NVIDIA GeForce GTX 1060 6GB
# 35           4GB GDDR5  165W               Nvidia GeForce GTX 980
# 36           4GB GDDR5  150W                        Radeon RX 570
# 37           4GB GDDR6   75W               GeForce GTX 1650 GDDR6
# 38           3GB GDDR5  120W          Nvidia GeForce GTX 1060 3GB
# 39           4GB GDDR5  145W               Nvidia GeForce GTX 970
# 40           4GB GDDR5   75W        GeForce GTX 1650 Gaming OC 4G
# 41           4GB GDDR5   75W           Nvidia GeForce GTX 1050 Ti
# 42           4GB GDDR5   80W  PowerColor Red Dragon Radeon RX 560
# 43           2GB GDDR5   75W            Gigabyte GeForce GTX 1050
# 44           4GB GDDR5   50W             PowerColor Radeon RX 550
# 45           2GB GDDR5   30W               Nvidia GeForce GT 1030
# 46     2x8GB DDR4-3200   NaN                                  NaN
# 47     2x8GB DDR4-3200   NaN                                  NaN
# 48  2x8GB LPDDR4X-3733   NaN                                  NaN
# 49     2x8GB DDR4-3200   NaN                                  NaN

# %%
df = df.drop(['Base/Boost', 'Memory', 'Buy'], axis=1)

# %%
df = df.rename({'Unnamed: 0':'GPUName'}, axis=1)

# %%
'''
Nvidia = []

for i in df['GPUName']:
    if "Nvidia" in i:
        print(i, 'Matched')
'''

Nvidia = df[df['GPUName'].str.contains("Nvidia")]
AMD = df[df['GPUName'].str.contains("AMD")]
Intel = df[df['GPUName'].str.contains("Intel")]

# %%
Nvidia2 = Nvidia

# %%
Nvidia2[Nvidia2['GPUName'].str.contains('Titan')]
# Out:
#                          GPUName  Score    GPU Power
# 2               Nvidia Titan RTX  79.3%  TU102  280W
# 4                 Nvidia Titan V  68.7%  GV100  250W
# 7                Nvidia Titan Xp  61.2%  GP102  250W
# 24  Nvidia GTX Titan X (Maxwell)  35.3%  GM200   250

# %%
Nvidia2
# Out:
#                           GPUName   Score    GPU Power
# 0         Nvidia GeForce RTX 3090  100.0%  GA102  350W
# 1         Nvidia GeForce RTX 3080   93.0%  GA102  320W
# 2                Nvidia Titan RTX   79.3%  TU102  280W
# 3      Nvidia GeForce RTX 2080 Ti   77.5%  TU102  260W
# 4                  Nvidia Titan V   68.7%  GV100  250W
# 5   Nvidia GeForce RTX 2080 Super   66.9%  TU104  250W
# 6         Nvidia GeForce RTX 2080   62.6%  TU104  225W
# 7                 Nvidia Titan Xp   61.2%  GP102  250W
# 8   Nvidia GeForce RTX 2070 Super   59.7%  TU104  215W
# 9      Nvidia GeForce GTX 1080 Ti   57.8%  GP102  250W
# 10        Nvidia GeForce RTX 2070   53.1%  TU106  185W
# 11  Nvidia GeForce RTX 2060 Super   50.6%  TU106  175W
# 12        Nvidia GeForce GTX 1080   45.3%  GP104  180W
# 13        Nvidia GeForce RTX 2060   44.9%  TU106  160W
# 14     Nvidia GeForce GTX 1070 Ti   41.9%  GP104  180W
# 15     Nvidia GeForce GTX 1660 Ti   38.0%  TU116  120W
# 16  Nvidia GeForce GTX 1660 Super   37.9%  TU116  125W
# 17        Nvidia GeForce GTX 1070   36.8%  GP104  150W
# 18   Nvidia GTX Titan X (Maxwell)   35.3%  GM200   250
# 19      Nvidia GeForce GTX 980 Ti   33.0%  GM200  250W
# 20        Nvidia GeForce GTX 1660   32.9%  TU116  120W
# 21  Nvidia GeForce GTX 1650 Super   28.5%  TU116  100W
# 22    Nvidia GeForce GTX 1060 6GB   26.5%  GP106  120W
# 23         Nvidia GeForce GTX 980   26.5%  GM204  165W
# 24          Nvidia GTX 1650 GDDR6   23.9%  TU117   75W
# 25    Nvidia GeForce GTX 1060 3GB   22.3%  GP106  120W
# 26         Nvidia GeForce GTX 970   22.2%  GM204  145W
# 27        Nvidia GeForce GTX 1650   20.9%  TU117   75W
# 28     Nvidia GeForce GTX 1050 Ti   16.1%  GP107   75W
# 29        Nvidia GeForce GTX 1050   12.2%  GP107   75W
# 30         Nvidia GeForce GT 1030    5.8%  GP108   30W

# %%
Nvidia2.loc[Nvidia2['GPUName']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-74f6bb23b8e4> in <module>
# ----> 1 Nvidia2.loc[Nvidia2['GPUName']]
#
# c:\python38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# c:\python38\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# c:\python38\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# c:\python38\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# c:\python38\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Nvidia GeForce RTX 3090', 'Nvidia GeForce RTX 3080',\n       'Nvidia Titan RTX', 'Nvidia GeForce RTX 2080 Ti', 'Nvidia Titan V',\n       'Nvidia GeForce RTX 2080 Super', 'Nvidia GeForce RTX 2080',\n       'Nvidia Titan Xp', 'Nvidia GeForce RTX 2070 Super',\n       'Nvidia GeForce GTX 1080 Ti', 'Nvidia GeForce RTX 2070',\n       'Nvidia GeForce RTX 2060 Super', 'Nvidia GeForce GTX 1080',\n       'Nvidia GeForce RTX 2060', 'Nvidia GeForce GTX 1070 Ti',\n       'Nvidia GeForce GTX 1660 Ti', 'Nvidia GeForce GTX 1660 Super',\n       'Nvidia GeForce GTX 1070', 'Nvidia GTX Titan X (Maxwell)',\n       'Nvidia GeForce GTX 980 Ti', 'Nvidia GeForce GTX 1660',\n       'Nvidia GeForce GTX 1650 Super', 'Nvidia GeForce GTX 1060 6GB',\n       'Nvidia GeForce GTX 980', 'Nvidia GTX 1650 GDDR6',\n       'Nvidia GeForce GTX 1060 3GB', 'Nvidia GeForce GTX 970',\n       'Nvidia GeForce GTX 1650', 'Nvidia GeForce GTX 1050 Ti',\n       'Nvidia GeForce GTX 1050', 'Nvidia GeForce GT 1030'],\n      dtype='object')] are in the [index]"
